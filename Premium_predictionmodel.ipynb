# %%
import pandas as pd
import numpy as ny 
import matplotlib as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as ny
# ----> 3 import matplotlib as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
x = pd.Series([1,5,9,63,21])
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x = pd.Series([1,5,9,63,21])
#       2 x
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ##Data exercise

# %%
data = pd.read_csv("Insurance.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = pd.read_csv("Insurance.csv")
#       2 data.head()
#
# NameError: name 'pd' is not defined

# %%
data.describe()
# Out:
#                  SEX      INSR_TYPE  INSURED_VALUE        PREMIUM  \
# count  293537.000000  293537.000000   2.935370e+05  293529.000000
# mean        0.510154    1201.714268   4.146088e+05    6476.056811
# std         0.645379       0.455481   8.353941e+05    9039.792585
# min         0.000000    1201.000000   0.000000e+00       0.000000
# 25%         0.000000    1201.000000   0.000000e+00     804.850000
# 50%         0.000000    1202.000000   2.000000e+05    3154.017000
# 75%         1.000000    1202.000000   5.854500e+05    8293.213000
# max         2.000000    1204.000000   2.500000e+08  227278.880000
#
#           OBJECT_ID      PROD_YEAR      SEATS_NUM  CARRYING_CAPACITY  \
# count  2.935370e+05  293431.000000  293397.000000      212172.000000
# mean   5.000237e+09    2001.394900       6.182504         648.037967
# std    1.683947e+05      10.305091      13.045420        4838.746032
# min    5.000018e+09    1950.000000       0.000000           0.000000
# ...

# %%
data['PREMIUM'].hist(bins=50)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(20,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel("Vehicle type")
ax1.set_ylabel("Count of owners")
ax1.set_title('Car owners by vehicle type')
temp1=data['TYPE_VEHICLE'].value_counts()
temp1.plot(kind='bar')
# Out:
# <Axes: title={'center': 'Car owners by vehicle type'}, xlabel='TYPE_VEHICLE', ylabel='Count of owners'>

# %%
temp1=data['TYPE_VEHICLE'].value_counts()
temp1
# Out:
# TYPE_VEHICLE
# Truck                        56992
# Pick-up                      54723
# Automobile                   53022
# Bus                          40427
# Motor-cycle                  37209
# Station Wagones              24801
# Trailers and semitrailers    14408
# Tanker                        4195
# Tractor                       3896
# Special construction          3857
# Trade plates                     7
# Name: count, dtype: int64

# %%
data.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# SEX                       0
# INSR_BEGIN                0
# INSR_END                  0
# EFFECTIVE_YR              1
# INSR_TYPE                 0
# INSURED_VALUE             0
# PREMIUM                   8
# OBJECT_ID                 0
# PROD_YEAR               106
# SEATS_NUM               140
# CARRYING_CAPACITY     81365
# TYPE_VEHICLE              0
# CCM_TON                   2
# MAKE                      0
# USAGE                     0
# CLAIM_PAID           271164
# dtype: int64

# %%
data.dtypes
# Out:
# SEX                    int64
# INSR_BEGIN            object
# INSR_END              object
# EFFECTIVE_YR          object
# INSR_TYPE              int64
# INSURED_VALUE        float64
# PREMIUM              float64
# OBJECT_ID              int64
# PROD_YEAR            float64
# SEATS_NUM            float64
# CARRYING_CAPACITY    float64
# TYPE_VEHICLE          object
# CCM_TON              float64
# MAKE                  object
# USAGE                 object
# CLAIM_PAID           float64
# dtype: object

# %%
m=data['PREMIUM'].mean()
m
# Out:
# np.float64(6476.056811245226)

# %%
data.shape
# Out:
# (293537, 16)
